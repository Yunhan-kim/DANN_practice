# %%
from library import *

# %%
dataset = sio.loadmat('2Moons_v2.mat')

# %%
x,y = dataset['x'],dataset['y']
xt,yt = dataset['xt'],dataset['yt']
X,X_adapt,Y = dataset['X'],dataset['X_adapt'],dataset['Y']

# %%
plt.plot(x[:,0],x[:,1],'o')
plt.plot(xt[:,0],xt[:,1],'o')
plt.plot(X[:,0],X[:,1],'o')
plt.plot(X_adapt[:,0],X_adapt[:,1],'o')

# %%
Y.shape
# Out:
# (1000, 1)

# %%
dataset['X_adapt'].shape
# Out:
# (1000, 2)

# %%
dataset.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'x', 'y', 'xt', 'yt', 'X', 'X_adapt', 'Y'])
