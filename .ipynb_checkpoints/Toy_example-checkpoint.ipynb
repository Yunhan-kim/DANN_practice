# %%
from utils import *
np.random.seed(10)
torch.manual_seed(10)

# %%
dataset = sio.loadmat('2Moons_v2.mat')

X_,X_adapt_ = dataset['X'], dataset['X_adapt']
Y_,yt_ = dataset['Y'].squeeze()-1, (1-dataset['yt'].squeeze())/2

# %% [markdown]
# ## Data plot

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
# Source domain
# label 1
plt.plot(X_[np.where(Y_==0)[0],0],X_[np.where(Y_==0)[0],1],'bo')
# label 2
plt.plot(X_[np.where(Y_==1)[0],0],X_[np.where(Y_==1)[0],1],'b+')

# Target domain
# label 1
plt.plot(X_adapt_[np.where(yt_==0)[0],0],X_adapt_[np.where(yt_==0)[0],1],'ro')
# label 2
plt.plot(X_adapt_[np.where(yt_==1)[0],0],X_adapt_[np.where(yt_==1)[0],1],'r+')

ax.set_aspect('equal')
plt.xlim([-9,9]), plt.ylim([-9,9])
plt.savefig('./fig/dataset_labeled.png')

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
# Source domain
# label 1
plt.plot(X_[np.where(Y_==0)[0],0],X_[np.where(Y_==0)[0],1],'bo')
# label 2
plt.plot(X_[np.where(Y_==1)[0],0],X_[np.where(Y_==1)[0],1],'b+')

# Target domain
plt.plot(X_adapt_[:,0],X_adapt_[:,1],'k.')

ax.set_aspect('equal')
plt.xlim([-9,9]), plt.ylim([-9,9])
plt.savefig('./fig/dataset_unlabeled.png')
plt.show()

# %% [markdown]
# ## Dataset

# %%
X = torch.tensor(X_).type(torch.float32)
X_adapt = torch.tensor(X_adapt_).type(torch.float32)
Y = torch.LongTensor(Y_)
yt = torch.LongTensor(yt_)

# %%
batch_size = 32

x_train_source, x_test_source, y_train_source, y_test_source = train_test_split(X,Y,test_size = 0.2) 
train_source = DataLoader(TensorDataset(x_train_source,y_train_source), batch_size=batch_size, shuffle=True)

x_train_target, x_test_target, y_train_target, y_test_target = train_test_split(X_adapt,yt,test_size = 0.2) 
train_target = DataLoader(x_train_target, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ># Source only

# %% [markdown]
# >### Model

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model,self).__init__()
        self.hidden = nn.Linear(2,15)
        self.out = nn.Linear(15,2)                
        
    def forward(self, x):
        h = self.hidden(x)
        h = F.relu(h)
        y = self.out(h)
        return y

# %%
model = Model()
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# >### Train

# %%
train_loss, train_acc = [],[]
            
num_epochs = 50
for epoch in range(num_epochs):                        
    
    model.train(True)
    running_loss = 0.0
    running_corrects = 0.0
    
    for batch_idx, (x, y) in enumerate(train_source):    
        
        x,y = Variable(x).cuda(),Variable(y).cuda()
        optimizer.zero_grad()       

        # forward                
        outputs = model(x)        
        _, preds = torch.max(outputs.data, 1)                                
        loss = criterion(outputs, y)        
        loss.backward()
        optimizer.step()

        # statistics
        running_loss += loss.data
        running_corrects += torch.sum(preds == y.data)          

    epoch_loss = running_loss / len(train_source.dataset)
    epoch_acc = running_corrects.cpu().numpy()/len(train_source.dataset)

    train_loss.append(epoch_loss)
    train_acc.append(epoch_acc)        
    if (epoch+1) % 10 == 0:
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)    
        print('{} Loss: {:.4f} Acc: {:.2f}%'.format('train', epoch_loss, 100*epoch_acc))
# Out:
# Epoch 10/50
# ----------
# train Loss: 0.0062 Acc: 94.62%
# Epoch 20/50
# ----------
# train Loss: 0.0034 Acc: 96.75%
# Epoch 30/50
# ----------
# train Loss: 0.0024 Acc: 97.75%
# Epoch 40/50
# ----------
# train Loss: 0.0017 Acc: 98.50%
# Epoch 50/50
# ----------
# train Loss: 0.0013 Acc: 99.00%

# %% [markdown]
# >### Test

# %%
def acc_source_only(x,y):
    model.eval()
    out_tmp = model(x.cuda())
    _, preds = torch.max(out_tmp.data, 1)                                    
    running_corrects = torch.sum(preds == y.cuda().data)
    acc = running_corrects.cpu().numpy()/len(x)
    return acc
    
print('Source Accuracy:{:.2f}%'.format(100*acc_source_only(x_test_source,y_test_source)))    
print('Target Accuracy:{:.2f}%'.format(100*acc_source_only(x_test_target,y_test_target)))
# Out:
# Source Accuracy:99.50%
# Target Accuracy:62.50%

# %% [markdown]
# >### Visualization

# %%
h = 0.01
x_range = np.arange(-9.5, 9.5, h)
xx, yy = np.meshgrid(x_range,x_range)

with torch.no_grad():
    out = model(torch.from_numpy(np.c_[xx.ravel(), yy.ravel()]).type(torch.float32).to(device))    
    z = out.max(1,keepdim = True)[1].cpu().numpy()
z = z.reshape(xx.shape)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

cntr  = plt.contourf(xx, yy, z,levels=1,alpha=0.3,cmap=plt.cm.get_cmap('coolwarm', 2))

# Source domain
# label 1
plt.plot(X_[np.where(Y_==0)[0],0],X_[np.where(Y_==0)[0],1],'bo')
# label 2
plt.plot(X_[np.where(Y_==1)[0],0],X_[np.where(Y_==1)[0],1],'b+')

# Target domain
plt.plot(X_adapt_[:,0],X_adapt_[:,1],'k.')

ax.set_aspect('equal')
plt.xlim([-9,9]), plt.ylim([-9,9])
plt.colorbar(cntr)

# for i in range(model.hidden.out_features):
#     w = model.hidden.weight[i].detach().cpu().numpy()
#     b = model.hidden.bias[i].detach().cpu().numpy()
#     y_tmp = -1/w[1]*(w[0]*x_range+b)
#     plt.plot(x_range,y_tmp,'--')

plt.savefig('./fig/result_source_only.png')
plt.show()

# %% [markdown]
# _____
# ># Domain adaptation

# %% [markdown]
# >### Model

# %%
from torch.autograd import Function
class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha
        return output, None

# %%
class DANN(nn.Module):
    def __init__(self):
        super(DANN,self).__init__()
        self.hidden = nn.Linear(2,15)
        self.hidden2 = nn.Linear(15,15)
        self.out = nn.Linear(15,2)                
        self.domain = nn.Linear(15,2)                
        
    def forward(self, x, alpha = 25):
        h = self.hidden(x)
        h = F.relu(h)
#         h = self.hidden2(h)
#         h = F.relu(h)
        y = self.out(h)
        d = self.domain(ReverseLayerF.apply(h,alpha))
        return y,d

# %%
model = DANN()
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4) 
scheduler = optim.lr_scheduler.MultiStepLR(optimizer,[40,400],gamma = 0.1)

# %% [markdown]
# >### Train

# %%
train_loss_c, train_loss_d = [],[]
train_loss, train_acc = [],[]
            
num_epochs = 800
for epoch in range(num_epochs):                        
    
    model.train(True)
    running_loss_c,running_loss_d,running_loss = 0.0,0.0,0.0
    running_corrects = 0.0
    
    for batch_idx, (source_data, target_data) in enumerate(zip(train_source,train_target)):    
        
        x_s,y_s = source_data
        x_s,y_s = Variable(x_s).cuda(),Variable(y_s).cuda()
        x_t = Variable(target_data).cuda()  
        
        optimizer.zero_grad()       

        # Classification
        outputs,_ = model(x_s)        
        _, preds = torch.max(outputs.data, 1)                                
        loss_c = criterion(outputs, y_s)        
        
        # Domain
        label_s = torch.zeros(x_s.shape[0]).type(torch.LongTensor).cuda()        
        _,out_domain = model(x_s)        
        loss_s = criterion(out_domain, label_s)        
        label_t = torch.ones(x_t.shape[0]).type(torch.LongTensor).cuda()        
        _,out_domain = model(x_t)        
        loss_t = criterion(out_domain, label_t)        
        loss_d = loss_s + loss_t
        
        loss = loss_c + loss_d
        
        loss.backward()
        optimizer.step()

        # statistics
        running_loss_c += loss_c.data
        running_loss_d += loss_d.data
        running_loss += loss.data
        running_corrects += torch.sum(preds == y_s.data)          
    
    scheduler.step()
    epoch_loss_c = running_loss_c / len(train_source.dataset)
    epoch_loss_d = running_loss_d / len(train_source.dataset)
    epoch_loss = running_loss / len(train_source.dataset)
    epoch_acc = running_corrects.cpu().numpy()/len(train_source.dataset)

    train_loss_c.append(epoch_loss_c)
    train_loss_d.append(epoch_loss_d)
    train_loss.append(epoch_loss)
    train_acc.append(epoch_acc)        
    if (epoch+1) % 20 == 0:
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)    
        print('{} Total Loss: {:.4f} Acc: {:.2f}%'.format('train', epoch_loss, 100*epoch_acc))
        print('Classification Loss: {:.4f} Domain Loss: {:.4f}'.format(epoch_loss_c, epoch_loss_d))
# Out:
# Epoch 20/800
# ----------
# train Total Loss: 0.0618 Acc: 79.12%
# Classification Loss: 0.0154 Domain Loss: 0.0464
# Epoch 40/800
# ----------
# train Total Loss: 0.0556 Acc: 93.25%
# Classification Loss: 0.0115 Domain Loss: 0.0441
# Epoch 60/800
# ----------
# train Total Loss: 0.0550 Acc: 92.38%
# Classification Loss: 0.0112 Domain Loss: 0.0438
# Epoch 80/800
# ----------
# train Total Loss: 0.0546 Acc: 91.75%
# Classification Loss: 0.0110 Domain Loss: 0.0436
# Epoch 100/800
# ----------
# train Total Loss: 0.0541 Acc: 91.25%
# Classification Loss: 0.0107 Domain Loss: 0.0433
# Epoch 120/800
# ----------
# train Total Loss: 0.0536 Acc: 90.75%
# Classification Loss: 0.0105 Domain Loss: 0.0431
# Epoch 140/800
# ----------
# train Total Loss: 0.0532 Acc: 90.25%
# Classification Loss: 0.0103 Domain Loss: 0.0429
# Epoch 160/800
# ----------
# train Total Loss: 0.0527 Acc: 89.75%
# Classification Loss: 0.0101 Domain Loss: 0.0427
# Epoch 180/800
# ----------
# train Total Loss: 0.0523 Acc: 89.62%
# Classification Loss: 0.0099 Domain Loss: 0.0425
# Epoch 200/800
# ----------
# train Total Loss: 0.0520 Acc: 89.25%
# Classification Loss: 0.0097 Domain Loss: 0.0423
# Epoch 220/800
# ----------
# train Total Loss: 0.0516 Acc: 88.88%
# Classification Loss: 0.0095 Domain Loss: 0.0421
# Epoch 240/800
# ----------
# train Total Loss: 0.0512 Acc: 88.88%
# Classification Loss: 0.0093 Domain Loss: 0.0419
# Epoch 260/800
# ----------
# train Total Loss: 0.0509 Acc: 89.12%
# Classification Loss: 0.0092 Domain Loss: 0.0417
# Epoch 280/800
# ----------
# train Total Loss: 0.0506 Acc: 89.50%
# Classification Loss: 0.0090 Domain Loss: 0.0416
# Epoch 300/800
# ----------
# train Total Loss: 0.0503 Acc: 89.75%
# Classification Loss: 0.0089 Domain Loss: 0.0414
# Epoch 320/800
# ----------
# train Total Loss: 0.0500 Acc: 90.00%
# Classification Loss: 0.0087 Domain Loss: 0.0413
# Epoch 340/800
# ----------
# train Total Loss: 0.0497 Acc: 90.12%
# Classification Loss: 0.0086 Domain Loss: 0.0412
# Epoch 360/800
# ----------
# train Total Loss: 0.0494 Acc: 90.38%
# Classification Loss: 0.0084 Domain Loss: 0.0410
# Epoch 380/800
# ----------
# train Total Loss: 0.0492 Acc: 90.88%
# Classification Loss: 0.0083 Domain Loss: 0.0409
# Epoch 400/800
# ----------
# train Total Loss: 0.0489 Acc: 90.88%
# Classification Loss: 0.0081 Domain Loss: 0.0408
# Epoch 420/800
# ----------
# train Total Loss: 0.0489 Acc: 90.88%
# Classification Loss: 0.0081 Domain Loss: 0.0408
# Epoch 440/800
# ----------
# train Total Loss: 0.0489 Acc: 90.88%
# Classification Loss: 0.0081 Domain Loss: 0.0408
# Epoch 460/800
# ----------
# train Total Loss: 0.0489 Acc: 91.00%
# Classification Loss: 0.0081 Domain Loss: 0.0408
# Epoch 480/800
# ----------
# train Total Loss: 0.0488 Acc: 91.00%
# Classification Loss: 0.0081 Domain Loss: 0.0408
# Epoch 500/800
# ----------
# train Total Loss: 0.0488 Acc: 91.00%
# Classification Loss: 0.0080 Domain Loss: 0.0408
# Epoch 520/800
# ----------
# train Total Loss: 0.0488 Acc: 91.00%
# Classification Loss: 0.0080 Domain Loss: 0.0408
# Epoch 540/800
# ----------
# train Total Loss: 0.0488 Acc: 91.25%
# Classification Loss: 0.0080 Domain Loss: 0.0407
# Epoch 560/800
# ----------
# train Total Loss: 0.0487 Acc: 91.38%
# Classification Loss: 0.0080 Domain Loss: 0.0407
# Epoch 580/800
# ----------
# train Total Loss: 0.0487 Acc: 91.38%
# Classification Loss: 0.0080 Domain Loss: 0.0407
# Epoch 600/800
# ----------
# train Total Loss: 0.0487 Acc: 91.38%
# Classification Loss: 0.0080 Domain Loss: 0.0407
# Epoch 620/800
# ----------
# train Total Loss: 0.0487 Acc: 91.38%
# Classification Loss: 0.0080 Domain Loss: 0.0407
# Epoch 640/800
# ----------
# train Total Loss: 0.0486 Acc: 91.50%
# Classification Loss: 0.0079 Domain Loss: 0.0407
# Epoch 660/800
# ----------
# train Total Loss: 0.0486 Acc: 91.62%
# Classification Loss: 0.0079 Domain Loss: 0.0407
# Epoch 680/800
# ----------
# train Total Loss: 0.0486 Acc: 91.75%
# Classification Loss: 0.0079 Domain Loss: 0.0407
# Epoch 700/800
# ----------
# train Total Loss: 0.0486 Acc: 91.75%
# Classification Loss: 0.0079 Domain Loss: 0.0407
# Epoch 720/800
# ----------
# train Total Loss: 0.0485 Acc: 91.75%
# Classification Loss: 0.0079 Domain Loss: 0.0407
# Epoch 740/800
# ----------
# train Total Loss: 0.0485 Acc: 91.75%
# Classification Loss: 0.0079 Domain Loss: 0.0406
# Epoch 760/800
# ----------
# train Total Loss: 0.0485 Acc: 91.75%
# Classification Loss: 0.0079 Domain Loss: 0.0406
# Epoch 780/800
# ----------
# train Total Loss: 0.0485 Acc: 91.75%
# Classification Loss: 0.0078 Domain Loss: 0.0406
# Epoch 800/800
# ----------
# train Total Loss: 0.0484 Acc: 91.75%
# Classification Loss: 0.0078 Domain Loss: 0.0406

# %%
plt.plot(torch.stack(train_loss).cpu().numpy())
plt.plot(torch.stack(train_loss_c).cpu().numpy())
plt.plot(torch.stack(train_loss_d).cpu().numpy())
plt.legend(['Total','Class','Domain'])

# %% [markdown]
# >### Test

# %%
def acc_dann(x,y):
    model.eval()
    out_tmp,_ = model(x.cuda())
    _, preds = torch.max(out_tmp.data, 1)                                    
    running_corrects = torch.sum(preds == y.cuda().data)
    acc = running_corrects.cpu().numpy()/len(x)
    return acc

def acc_dann_domain_tmp(x,domain):
    model.eval()
    _,out_tmp = model(x.cuda())
    _, preds = torch.max(out_tmp.data, 1)                                    
    if domain == 'source':        
        running_corrects = torch.sum(preds == torch.zeros(x.shape[0]).type(torch.LongTensor).cuda())
    if domain == 'target':        
        running_corrects = torch.sum(preds == torch.ones(x.shape[0]).type(torch.LongTensor).cuda())
    acc_tmp = running_corrects.cpu().numpy()
    return acc_tmp

domain_acc_tmp = acc_dann_domain_tmp(x_test_source,'source')+acc_dann_domain_tmp(x_test_target,'target')

print('Source Accuracy:{:.2f}%'.format(100*acc_dann(x_test_source,y_test_source))) 
print('Target Accuracy:{:.2f}%'.format(100*acc_dann(x_test_target,y_test_target)))
print('-'*10)
print('Domain Accuracy:{:.2f}%'.format(100*domain_acc_tmp/(len(x_test_source)+len(x_test_target))))
# Out:
# Source Accuracy:89.50%
# Target Accuracy:91.00%
# ----------
# Domain Accuracy:70.50%

# %% [markdown]
# >### Visualization

# %%
h = 0.01
x_range = np.arange(-9.5, 9.5, h)
xx, yy = np.meshgrid(x_range,x_range)

with torch.no_grad():
    out,_ = model(torch.from_numpy(np.c_[xx.ravel(), yy.ravel()]).type(torch.float32).to(device))    
    z = out.max(1,keepdim = True)[1].cpu().numpy()
z = z.reshape(xx.shape)

# %%
#===== Classification ======#
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

cntr  = plt.contourf(xx, yy, z,levels=1,alpha=0.3,cmap=plt.cm.get_cmap('coolwarm', 2))

# Source domain
# label 1
plt.plot(X_[np.where(Y_==0)[0],0],X_[np.where(Y_==0)[0],1],'bo')
# label 2
plt.plot(X_[np.where(Y_==1)[0],0],X_[np.where(Y_==1)[0],1],'b+')

# Target domain
plt.plot(X_adapt_[:,0],X_adapt_[:,1],'k.')

ax.set_aspect('equal')
plt.xlim([-9,9]), plt.ylim([-9,9])
plt.colorbar(cntr)

# for i in range(model.hidden.out_features):
#     w = model.hidden.weight[i].detach().cpu().numpy()
#     b = model.hidden.bias[i].detach().cpu().numpy()
#     y_tmp = -1/w[1]*(w[0]*x_range+b)
#     plt.plot(x_range,y_tmp,'--')

plt.savefig('./fig/result_dann.png')
plt.show()

# %%
#====== Domain ======#
h = 0.01
x_range = np.arange(-9.5, 9.5, h)
xx, yy = np.meshgrid(x_range,x_range)

with torch.no_grad():
    _,out = model(torch.from_numpy(np.c_[xx.ravel(), yy.ravel()]).type(torch.float32).to(device))    
    z = out.max(1,keepdim = True)[1].cpu().numpy()
z = z.reshape(xx.shape)
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

cntr  = plt.contourf(xx, yy, z,levels=1,alpha=0.3,cmap=plt.cm.get_cmap('copper', 8))

# Source domain
# label 1
plt.plot(X_[np.where(Y_==0)[0],0],X_[np.where(Y_==0)[0],1],'bo')
# label 2
plt.plot(X_[np.where(Y_==1)[0],0],X_[np.where(Y_==1)[0],1],'b+')

# Target domain
plt.plot(X_adapt_[:,0],X_adapt_[:,1],'k.')

ax.set_aspect('equal')
plt.xlim([-9,9]), plt.ylim([-9,9])
plt.colorbar(cntr)

# for i in range(model.hidden.out_features):
#     w = model.hidden.weight[i].detach().cpu().numpy()
#     b = model.hidden.bias[i].detach().cpu().numpy()
#     y_tmp = -1/w[1]*(w[0]*x_range+b)
#     plt.plot(x_range,y_tmp,'--')

plt.savefig('./fig/result_dann_domain.png')
plt.show()
